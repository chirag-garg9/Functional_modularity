# %%
import numpy as np

data = np.load('.\data\dsprites.npz', allow_pickle=True, encoding="latin1")

# %%
print(data.keys())
# Out:
# KeysView(NpzFile '.\\data\\dsprites.npz' with keys: metadata, imgs, latents_classes, latents_values)

# %%
# Out:
# [0 0 0 0 0 0]
